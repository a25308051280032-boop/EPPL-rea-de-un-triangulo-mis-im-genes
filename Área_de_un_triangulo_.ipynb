# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051280032-boop/EPPL-rea-de-un-triangulo-mis-im-genes/blob/main/%C3%81rea_de_un_triangulo_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Iris Chavez NL Fecha 25/Mar/2026♊
# ---
# # Calcular Area de un triangulo
# ---
# ![Area de un triangulo](https://codigoroot.net/blog/wp-content/uploads/2023/02/image-1.png)
# ---
# # Formula para calcular el area
# $A=b*h/2$
#
# ---
# ## Datos de entrada
# * $B?$ $H?$
# * $A$
# ---
# ## Diagrama de flujo en LuciChart
# ![DF Area de un triangulo](https://raw.githubusercontent.com/a25308051280032-boop/EPPL-rea-de-un-triangulo-mis-im-genes/refs/heads/main/DF%20%20Area%20de%20un%20triangulo.png)

# %%
# calcular area de un triangulo
# variables A, B, H,
# formulas A = B * H/2
# Capturar el valor de B, H
import math
print("Calcular Area de un triangulo")
B = float(input("Ingrese el  valor base: "))
H = float(input("Ingrese el  valor altura: "))
A = B * H/2

print("El area del triangulo es: ", A)

print("Iris Chavez NL = 11")
# Out:
# Calcular Area de un triangulo
# Ingrese el  valor base: 55
# Ingrese el  valor altura: 76
# El area del triangulo es:  2090.0
# Iris Chavez NL = 11

# %% [markdown]
# ## Relacion entre el codigo y el diagrama de flujo
# ![Relacion entre el DF y el codigo](https://raw.githubusercontent.com/a25308051280032-boop/EPPL-rea-de-un-triangulo-mis-im-genes/refs/heads/main/relacion%20entre%20el%20DF%20y%20el%20codigo.PNG)
